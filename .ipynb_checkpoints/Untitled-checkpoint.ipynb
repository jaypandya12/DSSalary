# %%
import glassdoor_scraper as gs
import pandas as pd

# %%
path = "C:/Users/jaypa/Desktop/ML/Projects/DSSalary/chromedriver"
slp_time = 1
df = gs.get_jobs('data scientist', 1000, False, path, slp_time)
# Out:
# Progress: 0/15
# Progress: 1/15
# Progress: 2/15
# Progress: 3/15
# Progress: 4/15
# Progress: 5/15
# Progress: 6/15
# Progress: 7/15
# Progress: 8/15
# Progress: 9/15
# Progress: 10/15
# Progress: 11/15
# Progress: 12/15
# Progress: 13/15
# Progress: 14/15
# Progress: 15/15

# %%
df
# Out:
#                Company Name                                 Competitors  \
# 0   Ericsson-Worldwide\n3.9     Huawei Technologies, IBM, Cisco Systems
# 1        Visible Alpha\n4.1          Morgan Stanley, UBS, Credit Suisse
# 2              Buckman\n3.5                                          -1
# 3          Blue Yonder\n4.3           SAP, Oracle, Manhattan Associates
# 4               PayPal\n3.6                       Square, Amazon, Apple
# 5                  GSK\n3.9                  Pfizer, AstraZeneca, Merck
# 6              HP Inc.\n4.1                                          -1
# 7               Amazon\n4.2                  Google, Microsoft, Walmart
# 8                   PK\n3.6                                          -1
# 9               h2o.ai\n4.1                                          -1
# 10              Amazon\n4.2                  Google, Microsoft, Walmart
# 11                TTEC\n3.4          Teleperformance, TaskUs, Convergys
# ...
